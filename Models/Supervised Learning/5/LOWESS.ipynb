# %% [markdown]
# # Supervised Learning:

# %% [markdown]
# **5. Implement the non-parametric locally weighted regression algorithm in order to fit data points.
# Select appropriate data set for your experiment and draw graphs**

# %% [markdown]
# We used LOWESS (Locally Weighted Scatterplot Smoothing), a non-parametric regression technique, on a synthetic dataset. LOWESS fits local regression models, adapting to nearby points to reveal trends and smooth noise. This demonstrates its effectiveness in analyzing noisy data without explicit assumptions.

# %% [markdown]
# *********************************************

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.nonparametric.smoothers_lowess import lowess

# %%
df = pd.read_csv('dataset.csv')

# %%
df.head()
# Out:
#           X          Y
# 0  0.000000   8.820262
# 1  0.204082   2.429774
# 2  0.408163   5.793315
# 3  0.612245  12.616378
# 4  0.816327  11.303638

# %%
X = df['X'].values
Y = df['Y'].values

# %%
smoothed = lowess(Y, X, frac=0.1)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(X, Y, label='Original Data', color='blue')
plt.plot(smoothed[:, 0], smoothed[:, 1], color='red', label='LOWESS Smoothing')
plt.title('LOWESS Smoothing')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.grid(True)
plt.show()
